# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PIL

import keras
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Activation
from keras.layers import Dropout, Dense, Flatten, BatchNormalization

# %%
train_dir = 'F:\Assignment2_AI\dataset\DATASET\DATASET\TRAIN'
test_dir = 'F:\Assignment2_AI\dataset\DATASET\DATASET\TEST'

# %%
batch_size = 32
img_height = 64
img_width = 64

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 22564 files belonging to 2 classes.
# Using 18052 files for training.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2513 files belonging to 2 classes.
# Using 502 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['O', 'R']

# %%
plt.figure(figsize= (10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype('uint8'))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
from tensorflow.keras import layers

# Use the Rescaling layer without experimental
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
X_train, y_train = next(iter(normalized_ds))
first_image = X_train[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0074697463 1.0

# %%
normalized_test = test_ds.map(lambda x, y: (normalization_layer(x), y))
X_test, y_test = next(iter(normalized_test))
first_img = X_test[0]
print(np.min(first_img), np.max(first_img))
# Out:
# 0.0 1.0

# %%
model = Sequential([                
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(64, 64, 3)), 
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
  tf.keras.layers.MaxPool2D((2,2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(units=128, activation="relu"),
  tf.keras.layers.Dense(units=64, activation="relu"),
  tf.keras.layers.Dense(units=1, activation="sigmoid")
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

# %%
history = model.fit(
    X_train, y_train,
    epochs = 30,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4375 - loss: 0.6968 - val_accuracy: 0.3438 - val_loss: 0.8878
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5625 - loss: 0.7333 - val_accuracy: 0.6875 - val_loss: 0.6867
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8750 - loss: 0.6668 - val_accuracy: 0.6562 - val_loss: 0.6516
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5625 - loss: 0.6650 - val_accuracy: 0.7188 - val_loss: 0.6638
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8438 - loss: 0.6362 - val_accuracy: 0.3438 - val_loss: 0.7279
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.6250 - loss: 0.6222 - val_accuracy: 0.5625 - val_loss: 0.6903
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8125 - loss: 0.5805 - val_accuracy: 0.7500 - val_loss: 0.5967
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8125 - loss: 0.5460 - val_accuracy: 0.7188 - val_loss: 0.5960
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8438 - loss: 0.4945 - val_accuracy: 0.5312 - val_loss: 0.7830
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7812 - loss: 0.4698 - val_accuracy: 0.7500 - val_loss: 0.6241
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8438 - loss: 0.4131 - val_accuracy: 0.7188 - val_loss: 0.6174
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8438 - loss: 0.3905 - val_accuracy: 0.5625 - val_loss: 0.9890
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7812 - loss: 0.3917 - val_accuracy: 0.7188 - val_loss: 0.6493
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8438 - loss: 0.3638 - val_accuracy: 0.7500 - val_loss: 0.8099
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8750 - loss: 0.3137 - val_accuracy: 0.6250 - val_loss: 1.1364
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8438 - loss: 0.3273 - val_accuracy: 0.7500 - val_loss: 0.7680
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8750 - loss: 0.2951 - val_accuracy: 0.7188 - val_loss: 0.8730
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9375 - loss: 0.2556 - val_accuracy: 0.6250 - val_loss: 1.2767
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8438 - loss: 0.2747 - val_accuracy: 0.7188 - val_loss: 0.8698
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9375 - loss: 0.2225 - val_accuracy: 0.7188 - val_loss: 0.8521
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9375 - loss: 0.2094 - val_accuracy: 0.6875 - val_loss: 1.2182
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9062 - loss: 0.1926 - val_accuracy: 0.7188 - val_loss: 1.1046
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9688 - loss: 0.1564 - val_accuracy: 0.7188 - val_loss: 0.8733
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9688 - loss: 0.1549 - val_accuracy: 0.7188 - val_loss: 1.0251
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9688 - loss: 0.1171 - val_accuracy: 0.6875 - val_loss: 1.3182
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9688 - loss: 0.1258 - val_accuracy: 0.7500 - val_loss: 0.9556
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9688 - loss: 0.0943 - val_accuracy: 0.7500 - val_loss: 0.9495
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9688 - loss: 0.0833 - val_accuracy: 0.6875 - val_loss: 1.3109
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.7188 - val_loss: 1.1304
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.0514 - val_accuracy: 0.7188 - val_loss: 0.9532

# %%
loss, accuracy = model.evaluate(X_train,y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 1.0000
# Testing Accuracy:  0.7188

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
model2 = Sequential([
   tf.keras.layers.Conv2D(32, (3,3), input_shape=(64, 64, 3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Flatten(),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(64, activation="relu"),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(32, activation="relu"),
   tf.keras.layers.Dense(1, activation="sigmoid")
])

model2.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

model2.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 235,745 (920.88 KB)
#  Trainable params: 235,745 (920.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_2 = model2.fit(
    X_train, y_train,
    epochs = 30,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4375 - loss: 0.7079 - val_accuracy: 0.6562 - val_loss: 0.6663
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4375 - loss: 0.7056 - val_accuracy: 0.3438 - val_loss: 0.7019
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6250 - loss: 0.6910 - val_accuracy: 0.3438 - val_loss: 0.7196
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5938 - loss: 0.6819 - val_accuracy: 0.3438 - val_loss: 0.7243
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.5938 - loss: 0.6872 - val_accuracy: 0.3438 - val_loss: 0.7069
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6250 - loss: 0.6784 - val_accuracy: 0.3438 - val_loss: 0.6985
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6875 - loss: 0.6623 - val_accuracy: 0.4688 - val_loss: 0.6915
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5625 - loss: 0.6757 - val_accuracy: 0.3750 - val_loss: 0.6985
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.6250 - loss: 0.6695 - val_accuracy: 0.5312 - val_loss: 0.6865
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6875 - loss: 0.6693 - val_accuracy: 0.5625 - val_loss: 0.6781
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7812 - loss: 0.6323 - val_accuracy: 0.6250 - val_loss: 0.6638
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8125 - loss: 0.5837 - val_accuracy: 0.7188 - val_loss: 0.6479
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7500 - loss: 0.5942 - val_accuracy: 0.6250 - val_loss: 0.6580
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.7500 - loss: 0.5425 - val_accuracy: 0.7812 - val_loss: 0.5361
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8125 - loss: 0.4921 - val_accuracy: 0.4375 - val_loss: 0.8283
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.5938 - loss: 0.5167 - val_accuracy: 0.7500 - val_loss: 0.6180
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8750 - loss: 0.3827 - val_accuracy: 0.7812 - val_loss: 0.5275
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8125 - loss: 0.4356 - val_accuracy: 0.6250 - val_loss: 0.7596
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8438 - loss: 0.3918 - val_accuracy: 0.6250 - val_loss: 0.9390
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7500 - loss: 0.3862 - val_accuracy: 0.8125 - val_loss: 0.4771
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7812 - loss: 0.5031 - val_accuracy: 0.6250 - val_loss: 0.8757
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8438 - loss: 0.3100 - val_accuracy: 0.5625 - val_loss: 1.1976
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8438 - loss: 0.3752 - val_accuracy: 0.7812 - val_loss: 0.7004
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8750 - loss: 0.3072 - val_accuracy: 0.8438 - val_loss: 0.5360
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8125 - loss: 0.3814 - val_accuracy: 0.7188 - val_loss: 0.8992
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9062 - loss: 0.2514 - val_accuracy: 0.5938 - val_loss: 1.2340
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8125 - loss: 0.3616 - val_accuracy: 0.7812 - val_loss: 0.7223
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8438 - loss: 0.3065 - val_accuracy: 0.8125 - val_loss: 0.5937
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8438 - loss: 0.3265 - val_accuracy: 0.7812 - val_loss: 0.7120
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8750 - loss: 0.2740 - val_accuracy: 0.7188 - val_loss: 1.0256

# %%
loss, accuracy = model2.evaluate(X_train,y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model2.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.8438
# Testing Accuracy:  0.7188

# %%
plot_graphs(history_2, "accuracy")
plot_graphs(history_2, "loss")

# %%
model3 = Sequential([
   tf.keras.layers.Conv2D(32, (3,3), input_shape=(64, 64, 3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same'),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D((2,2)),
   tf.keras.layers.Flatten(),
   tf.keras.layers.Dropout(0.2),
   tf.keras.layers.Dense(64, activation="relu"),
   tf.keras.layers.Dense(32, activation="relu"),
   tf.keras.layers.Dense(1, activation="sigmoid")
])

model3.compile(optimizer='adam', loss = 'binary_crossentropy',
                   metrics = ['accuracy'])

model3.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236,769 (924.88 KB)
#  Trainable params: 236,257 (922.88 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
history_3 = model3.fit(
    X_train, y_train,
    epochs = 40,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5938 - loss: 0.9303 - val_accuracy: 0.6562 - val_loss: 0.6784
# Epoch 2/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7812 - loss: 0.3911 - val_accuracy: 0.6875 - val_loss: 0.6853
# Epoch 3/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9062 - loss: 0.1795 - val_accuracy: 0.6875 - val_loss: 0.6908
# Epoch 4/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 1.0000 - loss: 0.0921 - val_accuracy: 0.7500 - val_loss: 0.6904
# Epoch 5/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.6562 - val_loss: 0.6852
# Epoch 6/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 0.6562 - val_loss: 0.6809
# Epoch 7/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.6875 - val_loss: 0.6781
# Epoch 8/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.6875 - val_loss: 0.6769
# Epoch 9/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.6250 - val_loss: 0.6766
# Epoch 10/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6250 - val_loss: 0.6771
# Epoch 11/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6875 - val_loss: 0.6779
# Epoch 12/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.6875 - val_loss: 0.6794
# Epoch 13/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6250 - val_loss: 0.6807
# Epoch 14/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6250 - val_loss: 0.6827
# Epoch 15/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6250 - val_loss: 0.6857
# Epoch 16/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5000 - val_loss: 0.6883
# Epoch 17/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 9.0230e-04 - val_accuracy: 0.4688 - val_loss: 0.6908
# Epoch 18/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4688 - val_loss: 0.6929
# Epoch 19/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 1.0000 - loss: 5.3456e-04 - val_accuracy: 0.4688 - val_loss: 0.6943
# Epoch 20/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 5.9745e-04 - val_accuracy: 0.4688 - val_loss: 0.6960
# Epoch 21/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 1.0000 - loss: 2.9662e-04 - val_accuracy: 0.5000 - val_loss: 0.6975
# Epoch 22/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 3.7549e-04 - val_accuracy: 0.4375 - val_loss: 0.6990
# Epoch 23/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 1.0000 - loss: 3.6068e-04 - val_accuracy: 0.4688 - val_loss: 0.7003
# Epoch 24/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 1.0000 - loss: 2.0378e-04 - val_accuracy: 0.4688 - val_loss: 0.7010
# Epoch 25/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 1.0000 - loss: 2.3071e-04 - val_accuracy: 0.4688 - val_loss: 0.7016
# Epoch 26/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 1.6206e-04 - val_accuracy: 0.4062 - val_loss: 0.7020
# Epoch 27/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 1.4793e-04 - val_accuracy: 0.4062 - val_loss: 0.7026
# Epoch 28/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 1.4590e-04 - val_accuracy: 0.4062 - val_loss: 0.7029
# Epoch 29/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 1.0000 - loss: 9.1363e-05 - val_accuracy: 0.4062 - val_loss: 0.7029
# Epoch 30/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 1.0000 - loss: 1.4690e-04 - val_accuracy: 0.4062 - val_loss: 0.7025
# Epoch 31/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 1.0000 - loss: 8.8602e-05 - val_accuracy: 0.4062 - val_loss: 0.7019
# Epoch 32/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 1.0277e-04 - val_accuracy: 0.4062 - val_loss: 0.7011
# Epoch 33/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 1.0000 - loss: 8.6898e-05 - val_accuracy: 0.4062 - val_loss: 0.7001
# Epoch 34/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 6.5031e-05 - val_accuracy: 0.4375 - val_loss: 0.6991
# Epoch 35/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 6.4197e-05 - val_accuracy: 0.4375 - val_loss: 0.6983
# Epoch 36/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 1.0000 - loss: 7.4082e-05 - val_accuracy: 0.4375 - val_loss: 0.6976
# Epoch 37/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 5.2440e-05 - val_accuracy: 0.4688 - val_loss: 0.6968
# Epoch 38/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 1.0000 - loss: 9.2010e-05 - val_accuracy: 0.4688 - val_loss: 0.6959
# Epoch 39/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 4.3178e-05 - val_accuracy: 0.4375 - val_loss: 0.6951
# Epoch 40/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 6.2353e-05 - val_accuracy: 0.4375 - val_loss: 0.6941

# %%
loss, accuracy = model3.evaluate(X_test,y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Testing Accuracy:  0.4375

# %%
plot_graphs(history_3, "accuracy")
plot_graphs(history_3, "loss")
